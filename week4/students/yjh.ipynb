# %%
import numpy as np
import pandas as pd

# %%
particle=np.loadtxt('coord.out',skiprows=1, dtype=float)

# %%
x = particle[:,4]

# %%
x_prime = particle[:,5]

# %%
y = particle[:,6]

# %%
y_prime = particle[:,7]

# %%
fig = plt.figure(figsize = (10,10))

# %%
plt.subplot(2, 2, 1)
plt.hist(x,bins=None)
plt.title('')
plt.xlabel('x')
plt.ylabel('')
plt.grid()


plt.subplot(2, 2, 3)
plt.scatter(x,x_prime, s = 0.1)
plt.title('x,x_prime')
plt.xlabel('x')
plt.ylabel('x_prime')
plt.grid()

plt.subplot(2, 2, 4)
plt.hist( x_prime, bins=None, orientation = 'horizontal')
plt.title('')
plt.xlabel('')
plt.ylabel('x_prime')
plt.grid()

plt.tight_layout()

plt.show()

# %%
X = x/(0.0109)**0.5

# %%
X_PRIME = ((0.399 * x) + (0.0109 * x_prime))/(0.0109**0.5)

# %%
fig = plt.figure(figsize = (10,10))

# %%
plt.subplot(2, 2, 1)
plt.hist(X,bins=None)
plt.title('')
plt.xlabel('X')
plt.ylabel('')
plt.grid()


plt.subplot(2, 2, 3)
plt.scatter(X,X_PRIME, s = 0.1)
plt.title('X,X_PRIME')
plt.xlabel('X')
plt.ylabel('X_PRIME')
plt.grid()

plt.subplot(2, 2, 4)
plt.hist( X_PRIME, bins=None, orientation = 'horizontal')
plt.title('')
plt.xlabel('')
plt.ylabel('X_PRIME')
plt.grid()

plt.tight_layout()

plt.show()
